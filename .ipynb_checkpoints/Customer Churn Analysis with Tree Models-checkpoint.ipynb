# %% [markdown]
# # Phase 1: Importing the neccesaary libraries and data for my project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Telco-Customer-Churn.csv', 'Untitled.ipynb']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ginja\\Videos\\CAREER JOURNEY\\Target\\PERSONAL_PROJECT\\my Supervised Learning project'

# %%
df = pd.read_csv(r'C:\\Users\\Ginja\\Videos\\CAREER JOURNEY\\Target\\PERSONAL_PROJECT\\my Supervised Learning project\\Telco-Customer-churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Phase 1 (Part_2): Quick Data_Check

# %% [markdown]
# #### Meta data summary

# %%
# Meta data summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %% [markdown]
# #### statistical summary

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# # Phase 2 : Exploratory Data Analysis

# %% [markdown]
# #### Checking for mising values

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# #### Displaying the balance of the class labels (Churn) with a Count Plot

# %%
sns.countplot(data=df, x='Churn', hue = 'Churn', legend =False, palette= {'Yes':'red','No':'blue'})
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# #### The plot voilin below helps us understand whether churned customers generally are paying more or less than the loyal ones

# %%
 # the distribution of TotalCharges for each Churn category
sns.violinplot(data=df,x='Churn',y='TotalCharges')
# Out:
# <Axes: xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
# #### Plot below to show the correlation between features and the Target variable

# %% [markdown]
# ##### This will help us determine which features are most correlated with churn

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
corr_df  = pd.get_dummies(df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod','Churn']]).corr()

# %%
corr_df['Churn_Yes'].sort_values().iloc[1:-1]
# Out:
# Contract_Two year                         -0.301552
# StreamingMovies_No internet service       -0.227578
# StreamingTV_No internet service           -0.227578
# TechSupport_No internet service           -0.227578
# DeviceProtection_No internet service      -0.227578
# OnlineBackup_No internet service          -0.227578
# OnlineSecurity_No internet service        -0.227578
# InternetService_No                        -0.227578
# PaperlessBilling_No                       -0.191454
# Contract_One year                         -0.178225
# OnlineSecurity_Yes                        -0.171270
# TechSupport_Yes                           -0.164716
# Dependents_Yes                            -0.163128
# Partner_Yes                               -0.149982
# PaymentMethod_Credit card (automatic)     -0.134687
# InternetService_DSL                       -0.124141
# PaymentMethod_Bank transfer (automatic)   -0.118136
# PaymentMethod_Mailed check                -0.090773
# ...

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(x=corr_df['Churn_Yes'].sort_values().iloc[1:-1].index,y=corr_df['Churn_Yes'].sort_values().iloc[1:-1].values,
hue=corr_df['Churn_Yes'].sort_values().iloc[1:-1].index,legend=False, palette='Spectral')
plt.title("Feature Correlation to Yes Churn")
plt.xticks(rotation=90);

# %% [markdown]
# # Phase 3: Churn Analysis

# %% [markdown]
# #### To group customers based on how long they've stayed (their, tenure) and then analyze churn behavior within each group

# %% [markdown]
# ##### This help answer the question = do newer customers churn more than older ones

# %%
# All unique Contract type
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.histplot(data=df, x='tenure', bins=60, hue='Churn', palette={'Yes': 'red', 'No': 'blue'}, multiple='stack')
plt.title('Customer Tenure Distribution by Churn Status')
plt.xlabel('Tenure (Months)')
plt.ylabel('Number of Customers')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.displot(data=df,x='tenure',bins=70,col='Contract',row='Churn');

# %% [markdown]
# ##### Below is a scatter plot of Total Charges versus Monthly Charges, and color hue by Churn.

# %% [markdown]
# ##### This helps to reveal visually the patterns in customer behavior related to spending and churn

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.scatterplot(data=df, x='MonthlyCharges',y='TotalCharges',hue='Churn',linewidth=0.5,alpha=0.5,palette='Dark2')
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# we can spot the following =>
# 1.Customers who paid a lot but still churned (rare and concerning)
# 2.Customers who paid little and churned early (common)

# %% [markdown]
# #### Creating Cohorts based on Tenure

# %% [markdown]
# ##### This helps answer:
#
# "Are newer customers more likely to churn?"
#
# "Does customer loyalty increase over time?"

# %%
no_churn = df.groupby(['Churn','tenure']).count().transpose()['No']
yes_churn = df.groupby(['Churn','tenure']).count().transpose()['Yes']

# %%
# calculating the churn rate (%) per tenure month.
churn_rate = 100 * yes_churn / (no_churn+yes_churn)

# %%
churn_rate.transpose()['customerID']
# Out:
# tenure
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: customerID, Length: 72, dtype: float64

# %% [markdown]
# ##### A plot below showing churn rate per months of tenure.

# %%
plt.figure(figsize=(10,4), dpi=200)
churn_rate.iloc[0].plot()
plt.ylabel('Churn Percentage')
# Out:
# Text(0, 0.5, 'Churn Percentage')

# %% [markdown]
# #### Broader Cohort Groups
# From the existing tenure column values, i created a new column called Tenure Cohort to form 4 separate categories:
#    * '0-12 Months'
#    * '24-48 Months'
#    * '12-24 Months'
#    * 'Over 48 Months'

# %%
def cohort(tenure):
    if tenure < 13:
        return '0-12 Months'
    elif tenure < 25:
        return '12-24 Months'
    elif tenure < 49:
        return '24-48 Months'
    else:
        return "Over 48 Months"

# %%
df['Tenure Cohort'] = df['tenure'].apply(cohort)

# %%
df.head(10)[['tenure','Tenure Cohort']]
# Out:
#    tenure   Tenure Cohort
# 0       1     0-12 Months
# 1      34    24-48 Months
# 2       2     0-12 Months
# 3      45    24-48 Months
# 4       2     0-12 Months
# 5       8     0-12 Months
# 6      22    12-24 Months
# 7      10     0-12 Months
# 8      28    24-48 Months
# 9      62  Over 48 Months

# %% [markdown]
# ##### A scatterplot of Total Charges versus Monthly Charts,colored by Tenure Cohort defined in the previous task.

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.scatterplot(data=df,x='MonthlyCharges',y='TotalCharges',hue='Tenure Cohort', linewidth=0.5,alpha=0.5,palette='Dark2')
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# #### below is a count plot showing the churn count per cohort.

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(data=df,x='Tenure Cohort',hue='Churn')
# Out:
# <Axes: xlabel='Tenure Cohort', ylabel='count'>

# %% [markdown]
# #### Below is a grid of Count Plots showing counts per Tenure Cohort, separated out by contract type and colored by the Churn hue.

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.catplot(data=df,x='Tenure Cohort',hue='Churn',col='Contract',kind='count')

# %% [markdown]
# # Phase 4: Predictive Modeling

# %% [markdown]
# #### Goal here is to explore 4 different tree based methods:
#    * A Single Decision Tree
#    * Random Forest
#    * AdaBoost
#    * Gradient Boosting

# %% [markdown]
# ##### Single Decision Tree

# %%
# Separating out the data into X features and Y label
# Creating dummy variables where necessary and noting which features are not useful and should be dropped
X = df.drop(['Churn','customerID'],axis=1)
X = pd.get_dummies(X,drop_first=True)

# %%
y = df['Churn']

# %%
# train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.10,random_state=42)

# %% [markdown]
# #### For each model we :
#
#    1. Train a the tree model.
#    2. Evaluate performance metrics

# %%
# Training a single decision tree model
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier(max_depth=6,random_state=42)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
pred= dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay,classification_report

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.90      0.86       511
#          Yes       0.63      0.47      0.54       193
#
#     accuracy                           0.78       704
#    macro avg       0.73      0.68      0.70       704
# weighted avg       0.77      0.78      0.77       704

# %%
ConfusionMatrixDisplay.from_estimator(dt, X_test, y_test, cmap='Blues')

# %%
# a DataFrame (imp_feats) that shows how important each feature is to the decision tree model
imp_feats = pd.DataFrame(data=dt.feature_importances_,index=X.columns,columns=['Feature Importance']).sort_values("Feature Importance")

# %%
plt.figure(figsize=(14,6), dpi=200)
sns.barplot(
    data=imp_feats.sort_values('Feature Importance'),
    x=imp_feats.sort_values('Feature Importance').index,
    y='Feature Importance', hue= imp_feats.sort_values('Feature Importance').index, legend=False,
    palette='Spectral'
)
plt.xticks(rotation=90)
plt.title("Feature Importance for Decision Tree");

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8),dpi=150)
plot_tree(dt,filled=True,feature_names=X.columns);

# %% [markdown]
# ## Random Forest
#
# #### Similarly, my goal here is to create a Random Forest model and create a classification report and confusion matrix from its predicted results on the test set

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100,random_state=42)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_preds = rf.predict(X_test)

# %%
print(classification_report(y_test,rf_preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.91      0.86       511
#          Yes       0.66      0.46      0.54       193
#
#     accuracy                           0.79       704
#    macro avg       0.74      0.68      0.70       704
# weighted avg       0.77      0.79      0.77       704

# %%
ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test)

# %% [markdown]
# ### Boosted Trees
#
# Using AdaBoost to create a model and report back the classification report and plot a confusion matrix for its predicted results just like before

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier

# %%
ada = AdaBoostClassifier(algorithm='SAMME',estimator=100,random_state=42)

# %%
ada.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME')

# %%
ada_preds = ada_model.predict(X_test)

# %%
print(classification_report(y_test,ada_preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.91      0.86       511
#          Yes       0.65      0.46      0.54       193
#
#     accuracy                           0.78       704
#    macro avg       0.73      0.68      0.70       704
# weighted avg       0.77      0.78      0.77       704

# %%
ConfusionMatrixDisplay.from_estimator(ada,X_test,y_test)

# %% [markdown]
# #### Conclusison as regards model performance
#
# * Random Forest performs slightly better overall, it has the best accuracy (.79) and precision for predicting churners.
# * However, all models struggle to recall churners well (only ~46–47%).
